# %% [markdown]
# # 노트북 이동 안내
#
# 이 노트북은 더 명확한 이름으로 옮겨졌습니다:
#
# **`01_intro.ipynb` → `01_fourier_transform.ipynb`**
#
# 내용은 동일합니다. 아래에서 새 파일을 열어주세요.
#
# ---
#
# ### 새 위치
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/dohyunKim0309/Fourier-Transform-Visualization/blob/main/examples/01_fourier_transform.ipynb)
#
# 또는 GitHub 에서 직접: <https://github.com/dohyunKim0309/Fourier-Transform-Visualization/blob/main/examples/01_fourier_transform.ipynb>
#
# ---
#
# > 이전에 공유받은 Colab 링크 (`01_intro.ipynb`) 를 통해 이 페이지에 도착하셨다면, 위 새 위치로 이동해주세요. 죄송합니다.
